# %% [markdown]
# Copyright (c) 2019 [윤기태]
#
# https://github.com/yoonkt200/python-data-analysis
#
# [MIT License](https://github.com/yoonkt200/python-data-analysis/blob/master/LICENSE.txt)

# %% [markdown]
# # (가제) 파이썬 데이터 분석

# %% [markdown]
# -----

# %% [markdown]
# # 2.2) 트위터 API로 연관 키워드 분석하기

# %% [markdown]
# ### 바로가기

# %% [markdown]
# - [<Step1. API 호출> : 트위터 API로 데이터 가져오기](#<Step1.-API-호출>-:-트위터-API로-데이터-가져오기)
#     - [API 데이터로 데이터 프레임 생성하기]
# - [<Step2. 추출> : 키워드 추출](#<Step2.-추출>-:-키워드-추출)
#     - [텍스트 데이터 전처리]
#     - [nltk, konlpy를 이용한 키워드 추출]
# - [<Step3. 분석> : 연관 분석을 이용한 키워드 분석](#<Step3.-분석>-:-연관-분석을-이용한-키워드-분석)
#     - [연관 키워드 추출하기]
#     - [단어 빈도 추출하기]
# - [<Step4. 시각화> : 연관 키워드 네트워크 시각화](#<Step4.-시각화>-:-연관-키워드-네트워크-시각화)
#     - [연관 키워드 네트워크 시각화]

# %% [markdown]
# -----

# %%
# -*- coding: utf-8 -*-

# 주피터 노트북을 실행한 브라우저에서 바로 그림을 볼 수 있게끔 만드는 것
#브라우저 내부(inline)에 바로 그려지도록 해주는 코드
# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # <Step1. API 호출> : 트위터 API로 데이터 가져오기

# %% [markdown]
# ### [API 데이터로 데이터 프레임 생성하기]
# - API 사용법 참고 : https://github.com/yoonkt200/python-data-analysis/blob/master/chapter_text/(%EC%B0%B8%EA%B3%A0)%20using-twitter-api.ipynb
# - 아래 코드 실행을 위해, anaconda prompt 혹은 Terminal에서 아래와 같은 패키지를 설치해 줍니다.
#     - (env_name) `pip install tweepy`
# - 혹은 아래의 코드로 라이브러리를 설치합니다.
# - [2022.02.04 ] tweepy 4 버전 설치시 api.search에서 에러 발생 => tweepy 3 버전으로 설치
# - pip install tweepy==3.10.0

# %%
#!pip install tweepy
# Out:
# Collecting tweepy
#   Downloading tweepy-4.5.0-py2.py3-none-any.whl (66 kB)
#      ---------------------------------------- 66.0/66.0 KB ? eta 0:00:00
# Collecting requests-oauthlib<2,>=1.0.0
#   Downloading requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Collecting requests<3,>=2.27.0
#   Downloading requests-2.27.1-py2.py3-none-any.whl (63 kB)
#      ---------------------------------------- 63.1/63.1 KB 3.3 MB/s eta 0:00:00
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\yj\anaconda3\lib\site-packages (from requests<3,>=2.27.0->tweepy) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\yj\anaconda3\lib\site-packages (from requests<3,>=2.27.0->tweepy) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\yj\anaconda3\lib\site-packages (from requests<3,>=2.27.0->tweepy) (3.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\yj\anaconda3\lib\site-packages (from requests<3,>=2.27.0->tweepy) (2.0.4)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.2.0-py3-none-any.whl (151 kB)
#      -------------------------------------- 151.5/151.5 KB 8.8 MB/s eta 0:00:00
# Installing collected packages: requests, oauthlib, requests-oauthlib, tweepy
#   Attempting uninstall: requests
#     Found existing installation: requests 2.26.0
#     Uninstalling requests-2.26.0:
#       Successfully uninstalled requests-2.26.0
# Successfully installed oauthlib-3.2.0 requests-2.27.1 requests-oauthlib-1.3.1 tweepy-4.5.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# conda-repo-cli 1.0.4 requires pathlib, which is not installed.
# anaconda-project 0.10.1 requires ruamel-yaml, which is not installed.

# %%
# tweepy 3 버전으로 설치
#!pip install tweepy==3.10.0
# Out:
# Collecting tweepy==3.10.0
#   Downloading tweepy-3.10.0-py2.py3-none-any.whl (30 kB)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\yj\anaconda3\lib\site-packages (from tweepy==3.10.0) (1.3.1)
# Requirement already satisfied: six>=1.10.0 in c:\users\yj\anaconda3\lib\site-packages (from tweepy==3.10.0) (1.16.0)
# Requirement already satisfied: requests[socks]>=2.11.1 in c:\users\yj\anaconda3\lib\site-packages (from tweepy==3.10.0) (2.27.1)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\yj\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->tweepy==3.10.0) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\yj\anaconda3\lib\site-packages (from requests[socks]>=2.11.1->tweepy==3.10.0) (3.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\yj\anaconda3\lib\site-packages (from requests[socks]>=2.11.1->tweepy==3.10.0) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\yj\anaconda3\lib\site-packages (from requests[socks]>=2.11.1->tweepy==3.10.0) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\yj\anaconda3\lib\site-packages (from requests[socks]>=2.11.1->tweepy==3.10.0) (1.26.7)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in c:\users\yj\anaconda3\lib\site-packages (from requests[socks]>=2.11.1->tweepy==3.10.0) (1.7.1)
# Installing collected packages: tweepy
#   Attempting uninstall: tweepy
#     Found existing installation: tweepy 4.5.0
#     Uninstalling tweepy-4.5.0:
#       Successfully uninstalled tweepy-4.5.0
# Successfully installed tweepy-3.10.0

# %% [markdown]
# -----

# %% [markdown]
# ##### 트위터 API 가져오기
# - 트위터의 키워드 크롤링 기능을 사용하기 위해 트위터 앱에서 발급받은 KEY와 TOKEN 정보를 입력
# - 총 4가지 정보를 입력하여 코드 실행
# - tweepy의 OAuthHandler() 클래스가 자동으로 개인정보 인증 완료

# %%
import tweepy

# 발급 완료된 키 입력
CONSUMER_KEY = "LUCHdCDyarrHrZtB3TphjDPDX"
CONSUMER_SECRET = "cEVd1dTmutWmiISeXlIk7UNZ5qbRlRVJVMg9l4Elvz5GU8doAd"
ACCESS_TOKEN_KEY = "169786640-GXkvSASVzzWCVgIgEtO91ENvZCEE4iGIFde9MDyW"
ACCESS_TOKEN_SECRET = "xC6ghbPWdEKBmBE8Oi6cVdgVVsRzFpmFLINHLcOksa4QA"

# 개인정보 인증을 요청하는 Handler
auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)

# 인증 요청을 수행
auth.set_access_token(ACCESS_TOKEN_KEY, ACCESS_TOKEN_SECRET)

# twitter API를 사용하기 위한 준비
api = tweepy.API(auth)

# %%
# tweepy 버전 출력
tweepy.__version__
# Out:
# '3.10.0'

# %% [markdown]
# -----

# %% [markdown]
# #### '손흥민' 키워드 검색

# %%
# Twitter Developer Platform의 Data dictionary 참조
# https://developer.twitter.com/en/docs/twitter-api/v1/data-dictionary/object-model/tweet

# twitter API를 사용하여 '손흥민' 이 포함된 트윗들을 크롤링한 뒤, 'user_mentions'와 'hashtags' 속성값 추출
keyword = "이재명"

# 특정 키워드 크롤링은  search() 함수 수행
tweets = api.search(keyword)

# entities() 함수로 특정 속성의 메타데이터에 접근하여 정보 추출
for tweet in tweets:
    print(tweet.text)
    print(tweet.entities['user_mentions'])
    print(tweet.entities['hashtags'])
    print(tweet.created_at) # 트윗이 생성된 UTC 시간, 예) "2022-02-04 01:47:09"
# Out:
# RT @Jaemyung_Lee: '나를 위한' 이재명의 소확행 공약! - 전세사기 편🏚
# 피, 땀, 눈물 흘려 마련한 전세보증금 지켜드립니다.
# 서민 주거 안정 위협하는 반사회적 범죄 전세사기😡
# 경기도지사 때 만든 ‘깡통전세 피해 예방 상담센터’ 전국…
# [{'screen_name': 'Jaemyung_Lee', 'name': '이재명', 'id': 106379129, 'id_str': '106379129', 'indices': [3, 16]}]
# []
# 2022-02-10 01:14:36
# RT @yukimjun: 정홍원, 이재명에 "이런 사람이 최고지도자?..상상만 해도 얼굴 화끈"
#
# 팩폭이네
# ㅋㅋㅋㅋ
# [{'screen_name': 'yukimjun', 'name': '한반도평화', 'id': 859946243098673153, 'id_str': '859946243098673153', 'indices': [3, 12]}]
# []
# 2022-02-10 01:14:36
# RT @blueang62716436: 김재원: 문프 지지하는 문파들중에 이재명은 죽어도 안뽑는다는 사람들 상대로, 이해찬이 어제 윤석열 발언을 두고 ‘저봐 윤석열 뽑으면 문프 큰일나~ 그러니까 이재명 뽑아야해’라고 공갈치는거라고 말함
#
# 그 문파들을…
# [{'screen_name': 'blueang62716436', 'name': 'blue_angel💙💚💙도깨비', 'id': 987994680783585282, 'id_str': '987994680783585282', 'indices': [3, 19]}]
# []
# 2022-02-10 01:14:36
# RT @woodyh98: 한국언론은 왜 반이재명을, 부동산 공화국을 간절히 유지해야 하는가에 대하여. https://t.co/SKZdQUy0BC
# [{'screen_name': 'woodyh98', 'name': '하작가', 'id': 118275399, 'id_str': '118275399', 'indices': [3, 12]}]
# []
# 2022-02-10 01:14:35
# RT @eternalMoonpa: @susuro11 쥬빌리로 자기 악성채무 청산했다구요?
# ㅋㅋㅋㅋㅋㅋㅋ 이재명 진짜
# 무슨 말을 해도 믿어지는 신기한 캐릭터.
# [{'screen_name': 'eternalMoonpa', 'name': '샴', 'id': 1403151256688807938, 'id_str': '1403151256688807938', 'indices': [3, 17]}, {'screen_name': 'susuro11', 'name': '조폭 싫어요', 'id': 730161295, 'id_str': '730161295', 'indices': [19, 28]}]
# []
# 2022-02-10 01:14:35
# RT @sukarbot: 추미애 아들은 휴가명령서 없는 휴가 19일, 이재명 아들은 인사명령서 없는 입원 52일. 이래저래 추미애와 이재명은 유유상종이었구나.
#
# 군 내부  “발목 재활을 위해 두 달간 자기 집 근처 군 병원에 입원할 수 있는 혜택을…
# [{'screen_name': 'sukarbot', 'name': '말랑말랑한 힘', 'id': 1041469676, 'id_str': '1041469676', 'indices': [3, 12]}]
# []
# 2022-02-10 01:14:35
# RT @Andrewkaf: 이재명 갤러리 이용자가 만든
# 이재명 포스터 중 일부 https://t.co/ESPwgkz8cW
# [{'screen_name': 'Andrewkaf', 'name': 'Andrew Kaf◆어용국민◆', 'id': 203131764, 'id_str': '203131764', 'indices': [3, 13]}]
# []
# 2022-02-10 01:14:34
# RT @RW_bot1: 재외선거 안내 받았다.
# 이재명 찍을거다.
# [{'screen_name': 'RW_bot1', 'name': '종교학 반인반봇', 'id': 457374828, 'id_str': '457374828', 'indices': [3, 11]}]
# []
# 2022-02-10 01:14:34
# RT @_ljmkskw__: 다행이다. 유인태 덕분에 이재명 최소 수천표는 떨어졌다.
#
# 유인태가 정신차릴까봐 걱정했다.
#
#  https://t.co/QG9suSnlTk
# [{'screen_name': '_ljmkskw__', 'name': '카르텔 v2.2', 'id': 854310076546404352, 'id_str': '854310076546404352', 'indices': [3, 14]}]
# []
# 2022-02-10 01:14:33
# RT @carmex611: 이재명 반대 현수막 거는데 후원한 이들을 계좌압색해서 죄다 고소ㆍ고발했다고? 이재명에 대한 그 많은 혐의에 대한 수사는 다 스톱이 되고 있으면서? 저런 자한테 진짜 권력을 주고 싶어?
# [{'screen_name': 'carmex611', 'name': 'N24', 'id': 3182234270, 'id_str': '3182234270', 'indices': [3, 13]}]
# []
# 2022-02-10 01:14:33
# RT @Jaemyung_Lee: 이낙연 전 대표님께서 총괄선대위원장직을 수락해 주셨습니다. 이보다 더 든든할 수 없습니다. 많은 경험과 경륜 가지고 계신 이낙연 위원장님께 진심으로 감사드립니다.
#
# 반드시 승리해 역사의 퇴행을 막고 한 발 한 발 전…
# [{'screen_name': 'Jaemyung_Lee', 'name': '이재명', 'id': 106379129, 'id_str': '106379129', 'indices': [3, 16]}]
# []
# 2022-02-10 01:14:32
# RT @TheMinjoo_Kr: #앞으로제대로
# #나를위해이재명
#
# 2월 10일(목) 이재명 더불어민주당 제20대 대통령 후보의 일정을 알려 드립니다. 당원과 국민 여러분의 많은 관심과 응원 부탁드립니다.
#
# #더불어민주당 #이재명 https://t.co…
# [{'screen_name': 'TheMinjoo_Kr', 'name': '더불어민주당', 'id': 68585222, 'id_str': '68585222', 'indices': [3, 16]}]
# [{'text': '앞으로제대로', 'indices': [18, 25]}, {'text': '나를위해이재명', 'indices': [26, 34]}, {'text': '더불어민주당', 'indices': [114, 121]}, {'text': '이재명', 'indices': [122, 126]}]
# 2022-02-10 01:14:32
# RT @Fiat_Lux_et_nox: @yyc1964 저 발언한 청와대 관계자가 박수현인가요? ㅋㅋㅋ 왜 그 관계자는 문프 뒤에 숨어요? 그 사람 정치인 아니예요? 문프가 저런 말 한 거 아니고 저 청와대 관계자 뇌피셜인데 왜 청와대 공식의견처럼 기…
# [{'screen_name': 'Fiat_Lux_et_nox', 'name': '꽃밭에호랑이 CARPE DIEM! MEMENTO MORI!', 'id': 201171533, 'id_str': '201171533', 'indices': [3, 19]}, {'screen_name': 'yyc1964', 'name': '윤영찬', 'id': 1214942134320562177, 'id_str': '1214942134320562177', 'indices': [21, 29]}]
# []
# 2022-02-10 01:14:31
# RT @Jaemyung_Lee: '나를 위한' 이재명의 소확행 공약! - 전세사기 편🏚
# 피, 땀, 눈물 흘려 마련한 전세보증금 지켜드립니다.
# 서민 주거 안정 위협하는 반사회적 범죄 전세사기😡
# 경기도지사 때 만든 ‘깡통전세 피해 예방 상담센터’ 전국…
# [{'screen_name': 'Jaemyung_Lee', 'name': '이재명', 'id': 106379129, 'id_str': '106379129', 'indices': [3, 16]}]
# []
# 2022-02-10 01:14:30
# RT @homobullaest: 이재명은 커녕 민주당것들도 안하는 얘기를 윤석열이 하네!
#  https://t.co/RHP3YxOmZV
# [{'screen_name': 'homobullaest', 'name': '떠오르는 섬 사람🏝', 'id': 50937679, 'id_str': '50937679', 'indices': [3, 16]}]
# []
# 2022-02-10 01:14:30

# %%
tweets
# Out:
# [Status(_api=<tweepy.api.API object at 0x00000162C72927C0>, _json={'created_at': 'Thu Feb 10 01:14:36 +0000 2022', 'id': 1491581333436448772, 'id_str': '1491581333436448772', 'text': "RT @Jaemyung_Lee: '나를 위한' 이재명의 소확행 공약! - 전세사기 편🏚\n피, 땀, 눈물 흘려 마련한 전세보증금 지켜드립니다.\n서민 주거 안정 위협하는 반사회적 범죄 전세사기😡\n경기도지사 때 만든 ‘깡통전세 피해 예방 상담센터’ 전국…", 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'Jaemyung_Lee', 'name': '이재명', 'id': 106379129, 'id_str': '106379129', 'indices': [3, 16]}], 'urls': []}, 'metadata': {'result_type': 'recent', 'iso_language_code': 'ko'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 3220427924, 'id_str': '3220427924', 'name': '#팩트of이지선', 'screen_name': 'makeup446', 'location': '대한민국 서울', 'description': '공정한 세상을 만들기 위해 늘 동참하겠습니다.', 'url': 'https://t.co/jnCFl7gorv', 'entities': {'url': {'urls': [{'url': 'https://t.co/jnCFl7gorv', 'expanded_url': 'https://www.youtube.com/channel/UCZLMISY_KapdV-X8aRhOVqA', 'display_url': 'youtube.com/channel/UCZLMI…', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 22797, 'friends_count': 12079, 'listed_count': 27, 'created_at': 'Tue May 19 14:26:24 +0000 2015', 'favourites_count': 25986, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 32845, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/722413222947467266/o9kzczPv_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/722413222947467266/o9kzczPv_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3220427924/1449125928', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Thu Feb 10 01:05:38 +0000 2022', 'id': 1491579073612574722, 'id_str': '1491579073612574722', 'text': "'나를 위한' 이재명의 소확행 공약! - 전세사기 편🏚\n피, 땀, 눈물 흘려 마련한 전세보증금 지켜드립니다.\n서민 주거 안정 위협하는 반사회적 범죄 전세사기😡\n경기도지사 때 만든 ‘깡통전세 피해 예방 상담센… https://t.co/WrYx0rJNJO", 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/WrYx0rJNJO', 'expanded_url': 'https://twitter.com/i/web/status/1491579073612574722', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'metadata': {'result_type': 'recent', 'iso_language_code': 'ko'}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 106379129, 'id_str': '106379129', 'name': '이재명', 'screen_name': 'Jaemyung_Lee', 'location': '대한민국 경기도', 'description': "이재명과 함께! '나를 위한 유세단' 모집중 😎 ▶️https://t.co/wD8zr2Ouk7", 'url': 'https://t.co/DuQIRl5ecW', 'entities': {'url': {'urls': [{'url': 'https://t.co/DuQIRl5ecW', 'expanded_url': 'https://www.ljm4you.com/', 'display_url': 'ljm4you.com', 'indices': [0, 23]}]}, 'description': {'urls': [{'url': 'https://t.co/wD8zr2Ouk ...
#  Status(_api=<tweepy.api.API object at 0x00000162C72927C0>, _json={'created_at': 'Thu Feb 10 01:14:36 +0000 2022', 'id': 1491581332518227968, 'id_str': '1491581332518227968', 'text': 'RT @yukimjun: 정홍원, 이재명에 "이런 사람이 최고지도자?..상상만 해도 얼굴 화끈"\n\n팩폭이네\nㅋㅋㅋㅋ', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'yukimjun', 'name': '한반도평화', 'id': 859946243098673153, 'id_str': '859946243098673153', 'indices': [3, 12]}], 'urls': []}, 'metadata': {'result_type': 'recent', 'iso_language_code': 'ko'}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 807489924, 'id_str': '807489924', 'name': '안태호', 'screen_name': 'athmtg1', 'location': '', 'description': '2014.4.16, 세월호, 안산 단원고는 잊지말자.  - 초면에 죄송할 필요 없어요. 안잡아먹어요.(....) - 인용알티를 하든 뭘 하든 상관없지만 최저한의 예의만 부탁드립니다.', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 19000, 'friends_count': 20706, 'listed_count': 58, 'created_at': 'Thu Sep 06 19:54:42 +0000 2012', 'favourites_count': 890, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 741310, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'FFFFFF', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme8/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme8/bg.gif', 'profile_background_tile': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1077671872118943744/KJGOIYdM_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1077671872118943744/KJGOIYdM_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/807489924/1399101648', 'profile_link_color': '575557', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'FFFFFF', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Wed Feb 09 09:41:25 +0000 2022', 'id': 1491346490496667648, 'id_str': '1491346490496667648', 'text': '정홍원, 이재명에 "이런 사람이 최고지도자?..상상만 해도 얼굴 화끈"\n\n팩폭이네\nㅋㅋㅋㅋ', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, 'metadata': {'result_type': 'recent', 'iso_language_code': 'ko'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 859946243098673153, 'id_str': '859946243098673153', 'name': '한반도평화', 'screen_name': 'yukimjun', 'location': '', 'description': '한반도 평화와 번영의 시대\n한반도 경제프로세스를 통한\n한반도 평화와 공존 그리고 공생', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 5100, 'friends_count': 4318, 'listed_count': 9, 'created_at': 'Thu May 04 01:42:16 +0000 2017', 'favourites_count': 56068, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 94134, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1404992205593268230/pqIvtcBr_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_i ...
#  Status(_api=<tweepy.api.API object at 0x00000162C72927C0>, _json={'created_at': 'Thu Feb 10 01:14:36 +0000 2022', 'id': 1491581331435782145, 'id_str': '1491581331435782145', 'text': 'RT @blueang62716436: 김재원: 문프 지지하는 문파들중에 이재명은 죽어도 안뽑는다는 사람들 상대로, 이해찬이 어제 윤석열 발언을 두고 ‘저봐 윤석열 뽑으면 문프 큰일나~ 그러니까 이재명 뽑아야해’라고 공갈치는거라고 말함\n\n그 문파들을…', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'blueang62716436', 'name': 'blue_angel💙💚💙도깨비', 'id': 987994680783585282, 'id_str': '987994680783585282', 'indices': [3, 19]}], 'urls': []}, 'metadata': {'result_type': 'recent', 'iso_language_code': 'ko'}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1176308938381217792, 'id_str': '1176308938381217792', 'name': '리터럴리', 'screen_name': '247Onlymoon', 'location': '', 'description': 'only moon', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count':
}]}, 'metadata': {'result_type': 'recent', 'iso_language_code': 'ko'}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1102231215988527104, 'id_str': '1102231215988527104', 'name': 'Janvier', 'screen_name': 'ygenarada', 'location': '어딘지 알아서 뭐하게', 'description': 'Être de gauche, c’est percevoir d’abord le pourtour des choses - Gilles Deleuze', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 31, 'friends_count': 83, 'listed_count': 0, 'created_at': 'Sun Mar 03 15:36:15 +0000 2019', 'favourites_count': 3351, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 4004, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1462219101460434944/8hF3vdef_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1462219101460434944/8hF3vdef_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1102231215988527104/1643025409', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Wed Feb 09 08:48:08 +0000 2022', ...
#  Status(_api=<tweepy.api.API object at 0x00000162C72927C0>, _json={'created_at': 'Thu Feb 10 01:14:35 +0000 2022', 'id': 1491581326922698754, 'id_str': '1491581326922698754', 'text': 'RT @eternalMoonpa: @susuro11 쥬빌리로 자기 악성채무 청산했다구요?\nㅋㅋㅋㅋㅋㅋㅋ 이재명 진짜 \n무슨 말을 해도 믿어지는 신기한 캐릭터.', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'eternalMoonpa', 'name': '샴', 'id': 1403151256688807938, 'id_str': '1403151256688807938', 'indices': [3, 17]}, {'screen_name': 'susuro11', 'name': '조폭 싫어요', 'id': 730161295, 'id_str': '730161295', 'indices': [19, 28]}], 'urls': []}, 'metadata': {'result_type': 'recent', 'iso_language_code': 'ko'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1290573683208069120, 'id_str': '1290573683208069120', 'name': '달토깨비🦋 문이 열리네🎁', 'screen_name': 'Iam644999', 'location': '지구별 동쪽 달님이 뜨는 나라', 'description': '💖자랑스러운 문재인보유국의 국민.                                     \n🌳거물에 걸리지않는 문파.                                        \n🥊문프님을 디스하는 놈들은 절대사절!\n\n🚫굿바이_이재명', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 1100, 'friends_count': 781, 'listed_count': 2, 'created_at': 'Tue Aug 04 09:02:11 +0000 2020', 'favourites_count': 95600, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 64124, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1485770077014167552/hn0t3KOg_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1485770077014167552/hn0t3KOg_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1290573683208069120/1642645032', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Wed Feb 09 21:07:43 +0000 2022', 'id': 1491519201093173250, 'id_str': '1491519201093173250', 'text': '@susuro11 쥬빌리로 자기 악성채무 청산했다구요?\nㅋㅋㅋㅋㅋㅋㅋ 이재명 진짜 \n무슨 말을 해도 믿어지는 신기한 캐릭터.', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'susuro11', 'name': '조폭 싫어요', 'id': 730161295, 'id_str': '730161295', 'indices': [0, 9]}], 'urls': []}, 'metadata': {'result_type': 'recent', 'iso_language_code': 'ko'}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': 1491437384302751746, 'in_reply_to_status_id_str': '1491437384302751746', 'in_reply_to_user_id': 730161295, 'in_reply_to_user_id_str': '730161295', 'in_reply_to_screen_name': 'susuro11', 'user': {'id': 1403151256688807938, 'id_str': '1403151256688807938', 'name': '샴', 'screen_name': 'eternalMoonpa', 'location': '과천 선관위 정문(오함마 들고 있음)', 'description': '이재명 찢는 계정, 대략 5년째 찢는 중. 민주당이 죽었네 탈당해야지.', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 1172, 'friends_count': 1248, 'listed_count': 4, 'created_at': 'Fri Jun 11 00:45:21 +0000 2021', 'favourites_count': 9279, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 9134, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translat ...
#  Status(_api=<tweepy.api.API object at 0x00000162C72927C0>, _json={'created_at': 'Thu Feb 10 01:14:35 +0000 2022', 'id': 1491581326008324098, 'id_str': '1491581326008324098', 'text': 'RT @sukarbot: 추미애 아들은 휴가명령서 없는 휴가 19일, 이재명 아들은 인사명령서 없는 입원 52일. 이래저래 추미애와 이재명은 유유상종이었구나.\n\n군 내부  “발목 재활을 위해 두 달간 자기 집 근처 군 병원에 입원할 수 있는 혜택을…', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 
 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 2774, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1491083227179753474/13ydXSBd_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1491083227179753474/13ydXSBd_normal.jpg', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Wed Feb 09 22:51:46 +0000 2022', 'id': 1491545388238651392, 'id_str': '1491545388238651392', 'text': '이재명 갤러리 이용자가 만든\n이재명 포스터 중 일부 http ...
#  Status(_api=<tweepy.api.API object at 0x00000162C72927C0>, _json={'created_at': 'Thu Feb 10 01:14:34 +0000 2022', 'id': 1491581321776353284, 'id_str': '1491581321776353284', 'text': 'RT @RW_bot1: 재외선거 안내 받았다.\n이재명 찍을거다.', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'RW_bot1', 'name': '종교학 반인반봇', 'id': 457374828, 'id_str': '457374828', 'indices': [3, 11]}], 'urls': []}, 'metadata': {'result_type': 'recent', 'iso_language_code': 'ko'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 151321111, 'id_str': '151321111', 'name': 'Sam Youn', 'screen_name': 'samsyoun', 'location': '', 'description': '', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 139, 'friends_count': 98, 'listed_count': 0, 'created_at': 'Thu Jun 03 04:00:02 +0000 2010', 'favourites_count': 10221, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 18969, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png', 'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': True, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Wed Feb 09 14:40:14 +0000 2022', 'id': 1491421686838984706, 'id_str': '1491421686838984706', 'text': '재외선거 안내 받았다.\n이재명 찍을거다.', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, 'metadata': {'result_type': 'recent', 'iso_language_code': 'ko'}, 'source': '<a href="http://itunes.apple.com/us/app/twitter/id409789998?mt=12" rel="nofollow">Twitter for Mac</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 457374828, 'id_str': '457374828', 'name': '종교학 반인반봇', 'screen_name': 'RW_bot1', 'location': 'Frankfurt on the Main, Germany', 'description': '종교학 봇 / 종교 봇 아님 / ARMY / 질문 및 비판, 반론엔 성의껏 답변을, 독설엔 더한 독설을, 아는척 같잖게 들이대는 분들에겐 벽돌을! / 너무 어이없을 땐 걍 쌩깜', 'url': 'https://t.co/KASNlrcWmL', 'entities': {'url': {'urls': [{'url': 'https://t.co/KASNlrcWmL', 'expanded_url': 'http://ask.fm/RWbot1', 'display_url': 'ask.fm/RWbot1', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 5858, 'friends_count': 4743, 'listed_count': 120, 'created_at': 'Sat Jan 07 10:12:56 +0000 2012', 'favourites_count': 931, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 116183, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '352726', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme5/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme5/bg.gif', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1738 ...
#  Status(_api=<tweepy.api.API object at 0x00000162C72927C0>, _json={'created_at': 'Thu Feb 10 01:14:33 +0000 2022', 'id': 1491581319624953859, 'id_str': '1491581319624953859', 'text': 'RT @_ljmkskw__: 다행이다. 유인태 덕분에 이재명 최소 수천표는 떨어졌다.\n\n유인태가 정신차릴까봐 걱정했다.\n\n https://t.co/QG9suSnlTk', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': '_ljmkskw__', 'name': '카르텔 v2.2', 'id': 854310076546404352, 'id_str': '854310076546404352', 'indices': [3, 14]}], 'urls': [{'url': 'https://t.co/QG9suSnlTk', 'expanded_url': 'https://news.v.daum.net/v/20220210093808035', 'display_url': 'news.v.daum.net/v/202202100938…', 'indices': [69, 92]}]}, 'metadata': {'result_type': 'recent', 'iso_language_code': 'ko'}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 844760244722970626, 'id_str': '844760244722970626', 'name': '대한민국 만악의 근원, 언론', 'screen_name': 'hyggelifes', 'location': '', 'description': '70년 적폐불패 카르텔 = 자·검·언·뉴라이트·토착왜구, 찢, 찬, 추, 털 따위들, 적폐에는 좌우가 없다. 이제 한구덩이 죄값의 가시무덤 속으로!', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 1451, 'friends_count': 2374, 'listed_count': 2, 'created_at': 'Thu Mar 23 03:58:32 +0000 2017', 'favourites_count': 72407, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 102680, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1449223940610486277/qXnAoox0_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1449223940610486277/qXnAoox0_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/844760244722970626/1634353804', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Thu Feb 10 01:14:16 +0000 2022', 'id': 1491581247696424964, 'id_str': '1491581247696424964', 'text': '다행이다. 유인태 덕분에 이재명 최소 수천표는 떨어졌다.\n\n유인태가 정신차릴까봐 걱정했다.\n\n https://t.co/QG9suSnlTk', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/QG9suSnlTk', 'expanded_url': 'https://news.v.daum.net/v/20220210093808035', 'display_url': 'news.v.daum.net/v/202202100938…', 'indices': [53, 76]}]}, 'metadata': {'result_type': 'recent', 'iso_language_code': 'ko'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 854310076546404352, 'id_str': '854310076546404352', 'name': '카르텔 v2.2', 'screen_name': '_ljmkskw__', 'location': '', 'description': '구독계 플텍계 기타 내멋대로 블언블. 구독계라 의심되도 블언블 또는 차단\n\n사회적 호로새끼 안사.', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 1453, 'friends_count': 152, 'listed_count': 3, 'created_at': 'Tue Apr 18 12:26:09 +0000 2017', 'favourites_count': 12232, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 170220, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_tran ...
#  Status(_api=<tweepy.api.API object at 0x00000162C72927C0>, _json={'created_at': 'Thu Feb 10 01:14:33 +0000 2022', 'id': 1491581318865436672, 'id_str': '1491581318865436672', 'text': 'RT @carmex611: 이재명 반대 현수막 거는데 후원한 이들을 계좌압색해서 죄다 고소ㆍ고발했다고? 이재명에 대한 그 많은 혐의에 대한 수사는 다 스톱이 되고 있으면서? 저런 자한테 진짜 권력을 주고 싶어?', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'carmex611', 'name': 'N24', 'id': 3182234270, 'id_str': '3182234270', 'indices': [3, 13]}], 'urls': []}, 'metadata': {'result_type': 'recent', 'iso_language_code': 'ko'}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 210064875, 'id_str': '210064875', 'name': 'M/IY', 'screen_name': 'itunomanii', 'location': 'Seoul', 'description': 'Love Yourself. 사람이 먼저다. Life goes on and let’s live on.', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 420, 'friends_count': 395, 'listed_count': 1, 'created_at': 'Sat Oct 30 14:00:20 +0000 2010', 'favourites_count': 24397, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 51909, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '0099B9', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme4/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme4/bg.gif', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1392390782640746506/pwE8mlzC_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1392390782640746506/pwE8mlzC_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/210064875/1574002218', 'profile_link_color': '0099B9', 'profile_sidebar_border_color': '5ED4DC', 'profile_sidebar_fill_color': '95E8EC', 'profile_text_color': '3C3940', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Wed Feb 09 13:57:37 +0000 2022', 'id': 1491410963895320581, 'id_str': '1491410963895320581', 'text': '이재명 반대 현수막 거는데 후원한 이들을 계좌압색해서 죄다 고소ㆍ고발했다고? 이재명에 대한 그 많은 혐의에 대한 수사는 다 스톱이 되고 있으면서? 저런 자한테 진짜 권력을 주고 싶어?', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, 'metadata': {'result_type': 'recent', 'iso_language_code': 'ko'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 3182234270, 'id_str': '3182234270', 'name': 'N24', 'screen_name': 'carmex611', 'location': '', 'description': '지치면 쉬어가자. 식물 기록.', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 6684, 'friends_count': 293, 'listed_count': 28, 'created_at': 'Sat May 02 00:25:12 +0000 2015', 'favourites_count': 277, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 107491, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/595806 ...
#  Status(_api=<tweepy.api.API object at 0x00000162C72927C0>, _json={'created_at': 'Thu Feb 10 01:14:32 +0000 2022', 'id': 1491581315514204160, 'id_str': '1491581315514204160', 'text': 'RT @Jaemyung_Lee: 이낙연 전 대표님께서 총괄선대위원장직을 수락해 주셨습니다. 이보다 더 든든할 수 없습니다. 많은 경험과 경륜 가지고 계신 이낙연 위원장님께 진심으로 감사드립니다. \n\n반드시 승리해 역사의 퇴행을 막고 한 발 한 발 전…', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'Jaemyung_Lee', 'name': '이재명', 'id': 106379129, 'id_str': '106379129', 'indices': [3, 16]}], 'urls': []}, 'metadata': {'result_type': 'recent', 'iso_language_code': 'ko'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 185956092, 'id_str': '185956092', 'name': '김세혁', 'screen_name': 'smart097', 'location': '대한민국 광주', 'description': '하나님을 경외하고 사람을 사랑하는 합동측 목사입니다.\n광주 광역시에서 태어남.\n장원초, 염주 초등학교 졸업,\n송원 중학교 졸업,\n창평 고등학교 졸업,\n성균관 대학교 법대,\n광신대학교 신학전공,\n광신대학교 상담심리치료전공', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count':
 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 234, 'friends_count': 120, 'listed_count': 0, 'created_at': 'Wed Nov 08 12:49:30 +0000 2017', 'favourites_count': 67352, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 82867, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1170928790161121283/AnrgLY5T_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1170928790161121283/AnrgLY5T_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/928243077457756160/1539603563', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Tue Feb 08 17:43:27 +0000 2022', 'id': 1491105410102611968, 'id_str': '1491105410102611968', 'text': '이재명은 커녕 민주당것들도 안하는 얘기를 윤석열이 하네!\n https://t.co/RHP3YxOmZV', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/RHP3YxOmZV', 'expanded_url': 'https://news.v.daum.net/v/20220208220709885?x_trkm=t', 'display_url': 'news.v.daum.net/v/202202082207…', 'indices': [33, 56]}]}, 'metadata': {'result_type': 'recent', 'iso_language_code': 'ko'}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 50937679, 'id_str': '50937679', 'name': '떠오르는 섬 사람🏝', 'screen_name': 'homobullaest', 'location': '도산', 'description': '메~렁~👻', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 310, 'friends_count': 432, 'listed_count': 8, 'created_at': 'Fri Jun 26 05:33:43 +0000 2009', 'favourites_count': 471, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 24701, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_ba ...

# %% [markdown]
# -----

# %% [markdown]
# ##### 데이터 프레임 형태로 수집

# %%
# 크롤링된 데이터를 저장할 데이터 프레임 생성
columns = ['created', 'tweet_text']
df = pd.DataFrame(columns=columns)

# 크롤링을 수행할 갯수를 입력
max_tweets = 1000

# Cursor 객체를 사용하여 크롤링 수행
# Cursor()로 keyword의 값에 해당하는 정보를  items()으로 지정한 갯수만큼 크롤링
searched_tweets = [status for status in tweepy.Cursor(api.search, q=keyword).items(max_tweets)]

# ‘손흥민’이 포함된 1000개의 트윗들에서, ‘text’, ‘created_at’ 정보를 데이터 프레임으로 저장
for tweet in searched_tweets:
    tweet_json = tweet._json
    tweet_text = tweet_json['text']
    created = tweet_json['created_at']
    row = [created, tweet_text]
    series = pd.Series(row, index=df.columns) #  created, tweet_text로 시리즈를 생성
    df = df.append(series, ignore_index=True) # 생성된 시리즈를 데이터프레임에 추가

# %%
# 데이터 프레임 상위 5개 출력
df.head()
# Out:
#                           created  \
# 0  Thu Feb 10 01:14:39 +0000 2022
# 1  Thu Feb 10 01:14:38 +0000 2022
# 2  Thu Feb 10 01:14:37 +0000 2022
# 3  Thu Feb 10 01:14:36 +0000 2022
# 4  Thu Feb 10 01:14:36 +0000 2022
#
#                                           tweet_text
# 0  RT @Citizen1Quiet: 이제 곧 한국대사관에 가서 이재명 찍을 날이 온다...
# 1  RT @uyhgw139vxlog: 이낙연과 거리를 좁혀 쬐끔만이라도 지지자를 땡겨 ...
# 2         RT @tadadadandan: 김혜경 이재명 구속이 아니면 속보가 아니지!
# 3  RT @Jaemyung_Lee: '나를 위한' 이재명의 소확행 공약! - 전세사기 ...
# 4  RT @yukimjun: 정홍원, 이재명에 "이런 사람이 최고지도자?..상상만 해도...

# %%
# 데이터 프레임을 csv 로 저장
# df.to_csv("tweet_temp.csv", index=False)

# %% [markdown]
# -----

# %% [markdown]
# # <Step2. 추출> : 키워드 추출

# %% [markdown]
# ### [텍스트 데이터 전처리]
# - 한글 문자열을 기준으로 키워드 추출 수행
# - tweet_text 데이터에서 한글 문자열만을 추출하여 ko_text 생성

# %%
#df = pd.read_csv("tweet_temp.csv")
#df.head()

# %%
# 정규표현 라이브러리
import re

# 텍스트 정제 함수 : 한글 및 띄어쓰기 이외의 문자는 전부 제거
def text_cleaning(text):
    hangul = re.compile('[^ ㄱ-ㅣ가-힣]+') # 한글의 정규표현식
    result = hangul.sub('', text)
    return result

# %%
# 텍스트 정제 함수text_cleaning()를 ‘tweet_text’ 피처에 이를 적용, 한글과 띄어쓰기만 추출하여 ko_text 피처 생성
df['ko_text'] = df['tweet_text'].apply(lambda x: text_cleaning(x))
df.head()
# Out:
#                           created  \
# 0  Thu Feb 10 01:14:39 +0000 2022
# 1  Thu Feb 10 01:14:38 +0000 2022
# 2  Thu Feb 10 01:14:37 +0000 2022
# 3  Thu Feb 10 01:14:36 +0000 2022
# 4  Thu Feb 10 01:14:36 +0000 2022
#
#                                           tweet_text  \
# 0  RT @Citizen1Quiet: 이제 곧 한국대사관에 가서 이재명 찍을 날이 온다...
# 1  RT @uyhgw139vxlog: 이낙연과 거리를 좁혀 쬐끔만이라도 지지자를 땡겨 ...
# 2         RT @tadadadandan: 김혜경 이재명 구속이 아니면 속보가 아니지!
# 3  RT @Jaemyung_Lee: '나를 위한' 이재명의 소확행 공약! - 전세사기 ...
# 4  RT @yukimjun: 정홍원, 이재명에 "이런 사람이 최고지도자?..상상만 해도...
#
#                                              ko_text
# 0    이제 곧 한국대사관에 가서 이재명 찍을 날이 온다절대로 윤석열 같은 쓰레기에게 ...
# 1    이낙연과 거리를 좁혀 쬐끔만이라도 지지자를 땡겨 가려는 이재명의 불순한 음모를 ...
# 2                            김혜경 이재명 구속이 아니면 속보가 아니지
# 3    나를 위한 이재명의 소확행 공약  전세사기 편피 땀 눈물 흘려 마련한 전세보증금...
# 4          정홍원 이재명에 이런 사람이 최고지도자상상만 해도 얼굴 화끈팩폭이네ㅋㅋㅋㅋ

# %% [markdown]
# -----

# %% [markdown]
# ### [konlpy를 이용한 키워드 추출]
# - 명사만 추출한 후 불용어 및 한글자 키워드 제거

# %%
from konlpy.tag import Okt
from collections import Counter

# 불용어 사전의 텍스트 문서 읽어 stopwords 리스트 생성
# 한국어 약식 불용어사전 예시 파일, 출처 - (https://www.ranks.nl/stopwords/korean)
korean_stopwords_path = "../data/korean_stopwords.txt"
with open(korean_stopwords_path, encoding='utf8') as f:
    stopwords = f.readlines()
stopwords = [x.strip() for x in stopwords] # strip()으로 공백 및 줄바꿈 제거

# 품사 중 명사만 추출하여 한글자 키워드 및 불용어 제거
# Okt(Open Korean Text)는 트위터에서 만든 오픈소스 한국어 처리기인 twitter-korean-text를 이어받아 만들고 있는 프로젝트

def get_nouns(x):
    # 명사만 추출
    nouns_tagger = Okt() # Okt()클래스 선언
    nouns = nouns_tagger.nouns(x)
    
    # 한글자 키워드 제거
    nouns = [noun for noun in nouns if len(noun) > 1]
    
    # 불용어를 제거
    nouns = [noun for noun in nouns if noun not in stopwords]
    
    return nouns

# %%
stopwords
# Out:
# ['아',
#  '휴',
#  '아이구',
#  '아이쿠',
#  '아이고',
#  '어',
#  '나',
#  '우리',
#  '저희',
#  '따라',
#  '의해',
#  '을',
#  '를',
#  '에',
#  '의',
#  '가',
#  '으로',
#  '로',
#  '에게',
#  '뿐이다',
#  '의거하여',
#  '근거하여',
#  '입각하여',
#  '기준으로',
#  '예하면',
#  '예를 들면',
#  '예를 들자면',
#  '저',
#  '소인',
#  '소생',
#  '저희',
#  '지말고',
#  '하지마',
#  '하지마라',
#  '다른',
#  '물론',
#  '또한',
#  '그리고',
#  '비길수 없다',
#  '해서는 안된다',
#  '뿐만 아니라',
#  '만이 아니다',
#  '만은 아니다',
#  '막론하고',
#  '관계없이',
#  '그치지 않다',
#  '그러나',
#  '그런데',
#  '하지만',
#  '든간에',
#  '논하지 않다',
#  '따지지 않다',
#  '설사',
#  '비록',
#  '더라도',
#  '아니면',
#  '만 못하다',
#  '하는 편이 낫다',
#  '불문하고',
#  '향하여',
#  '향해서',
#  '향하다',
#  '쪽으로',
#  '틈타',
#  '이용하여',
#  '타다',
#  '오르다',
#  '제외하고',
#  '이 외에',
#  '이 밖에',
#  '하여야',
#  '비로소',
#  '한다면 몰라도',
#  '외에도',
#  '이곳',
#  '여기',
#  '부터',
#  '기점으로',
#  '따라서',
#  '할 생각이다',
#  '하려고하다',
#  '이리하여',
#  '그리하여',
#  '그렇게 함으로써',
#  '하지만',
#  '일때',
#  '할때',
#  '앞에서',
#  '중에서',
#  '보는데서',
#  '으로써',
#  '로써',
#  '까지',
#  '해야한다',
#  '일것이다',
#  '반드시',
#  '할줄알다',
#  '할수있다',
#  '할수있어',
#  '임에 틀림없다',
#  '한다면',
#  '등',
#  '등등',
#  '제',
#  '겨우',
#  '단지',
#  '다만',
#  '할뿐',
#  '딩동',
#  '댕그',
#  '대해서',
#  '대하여',
#  '대하면',
#  '훨씬',
#  '얼마나',
#  '얼마만큼',
#  '얼마큼',
#  '남짓',
#  '여',
#  '얼마간',
#  '약간',
#  '다소',
#  '좀',
#  '조금',
#  '다수',
#  '몇',
#  '얼마',
#  '지만',
#  '하물며',
#  '또한',
#  '그러나',
#  '그렇지만',
#  '하지만',
#  '이외에도',
#  '대해 말하자면',
#  '뿐이다',
#  '다음에',
#  '반대로',
#  '반대로 말하자면',
#  '이와 반대로',
#  '바꾸어서 말하면',
#  '바꾸어서 한다면',
#  '만약',
#  '그렇지않으면',
#  '까악',
#  '툭',
#  '딱',
#  '삐걱거리다',
#  '보드득',
#  '비걱거리다',
#  '꽈당',
#  '응당',
#  '해야한다',
#  '에 가서',
#  '각',
#  '각각',
#  '여러분',
#  '각종',
#  '각자',
#  '제각기',
#  '하도록하다',
#  '와',
#  '과',
#  '그러므로',
#  '그래서',
#  '고로',
#  '한 까닭에',
#  '하기 때문에',
#  '거니와',
#  '이지만',
#  '대하여',
#  '관하여',
#  '관한',
#  '과연',
#  '실로',
#  '아니나다를가',
#  '생각한대로',
#  '진짜로',
#  '한적이있다',
#  '하곤하였다',
#  '하',
#  '하하',
#  '허허',
#  '아하',
#  '거바',
#  '와',
#  '오',
#  '왜',
#  '어째서',
#  '무엇때문에',
#  '어찌',
#  '하겠는가',
#  '무슨',
#  '어디',
#  '어느곳',
#  '더군다나',
#  '하물며',
#  '더욱이는',
#  '어느때',
#  '언제',
#  '야',
#  '이봐',
#  '어이',
#  '여보시오',
#  '흐흐',
#  '흥',
#  '휴',
#  '헉헉',
#  '헐떡헐떡',
#  '영차',
#  '여차',
#  '어기여차',
#  '끙끙',
#  '아야',
#  '앗',
#  '아야',
#  '콸콸',
#  '졸졸',
#  '좍좍',
#  '뚝뚝',
#  '주룩주룩',
#  '솨',
#  '우르르',
#  '그래도',
#  '또',
#  '그리고',
#  '바꾸어말하면',
#  '바꾸어말하자면',
#  '혹은',
#  '혹시',
#  '답다',
#  '및',
#  '그에 따르는',
#  '때가 되어',
#  '즉',
#  '지든지',
#  '설령',
#  '가령',
#  '하더라도',
#  '할지라도',
#  '일지라도',
#  '지든지',
#  '몇',
#  '거의',
#  '하마터면',
#  '인젠',
#  '이젠',
#  '된바에야',
#  '된이상',
#  '만큼\t어찌됏든',
#  '그위에',
#  '게다가',
#  '점에서 보아',
#  '비추어 보아',
#  '고려하면',
#  '하게될것이다',
#  '일것이다',
#  '비교적',
#  '좀',
#  '보다더',
#  '비하면',
#  '시키다',
#  '하게하다',
#  '할만하다',
#  '의해서',
#  '연이서',
#  '이어서',
#  '잇따라',
#  '뒤따라',
#  '뒤이어',
#  '결국',
#  '의지하여',
#  '기대여',
#  '통하여',
#  '자마자',
#  '더욱더',
#  '불구하고',
#  '얼마든지',
#  '마음대로',
#  '주저하지 않고',
#  '곧',
#  '즉시',
#  '바로',
#  '당장',
#  '하자마자',
#  '밖에 안된다',
#  '하면된다',
#  '그래',
#  '그렇지',
#  '요컨대',
#  '다시 말하자면',
#  '바꿔 말하면',
#  '즉',
#  '구체적으로',
#  '말하자면',
#  '시작하여',
#  '시초에',
#  '이상',
#  '허',
#  '헉',
#  '허걱',
#  '바와같이',
#  '해도좋다',
#  '해도된다',
#  '게다가',
#  '더구나',
#  '하물며',
#  '와르르',
#  '팍',
#  '퍽',
#  '펄렁',
#  '동안',
#  '이래',
#  '하고있었다',
#  '이었다',
#  '에서',
#  '로부터',
#  '까지',
#  '예하면',
#  '했어요',
#  '해요',
#  '함께',
#  '같이',
#  '더불어',
#  '마저',
#  '마저도',
#  '양자',
#  '모두',
#  '습니다',
#  '가까스로',
#  '하려고하다',
#  '즈음하여',
#  '다른',
#  '다른 방면으로',
#  '해봐요',
#  '습니까',
#  '했어요',
#  '말할것도 없고',
#  '무릎쓰고',
#  '개의치않고',
#  '하는것만 못하다',
#  '하는것이 낫다',
#  '매',
#  '매번',
#  '들',
#  '모',
#  '어느것',
#  '어느',
#  '로써',
#  '갖고말하자면',
#  '어디',
#  '어느쪽',
#  '어느것',
#  '어느해',
#  '어느 년도',
#  '라 해도',
#  '언젠가',
#  '어떤것',
#  '어느것',
#  '저기',
#  '저쪽',
#  '저것',
#  '그때',
#  '그럼',
#  '그러면',
#  '요만한걸',
#  '그래',
#  '그때',
#  '저것만큼',
#  '그저',
#  '이르기까지',
#  '할 줄 안다',
#  '할 힘이 있다',
#  '너',
#  '너희',
#  '당신',
#  '어찌',
#  '설마',
#  '차라리',
#  '할지언정',
#  '할지라도',
#  '할망정',
#  '할지언정',
#  '구토하다',
#  '게우다',
#  '토하다',
#  '메쓰겁다',
#  '옆사람',
#  '퉤',
#  '쳇',
#  '의거하여',
#  '근거하여',
#  '의해',
#  '따라',
#  '힘입어',
#  '그',
#  '다음',
#  '버금',
#  '두번째로',
#  '기타',
#  '첫번째로',
#  '나머지는',
#  '그중에서',
#  '견지에서',
#  '형식으로 쓰여',
#  '입장에서',
#  '위해서',
#  '단지',
#  '의해되다',
#  '하도록시키다',
#  '뿐만아니라',
#  '반대로',
#  '전후',
#  '전자',
#  '앞의것',
#  '잠시',
#  '잠깐',
#  '하면서',
#  '그렇지만',
#  '다음에',
#  '그러한즉',
#  '그런즉',
#  '남들',
#  '아무거나',
#  '어찌하든지',
#  '같다',
#  '비슷하다',
#  '예컨대',
#  '이럴정도로',
#  '어떻게',
#  '만약',
#  '만일',
#  '위에서 서술한바와같이',
#  '인 듯하다',
#  '하지 않는다면',
#  '만약에',
#  '무엇',
#  '무슨',
#  '어느',
#  '어떤',
#  '아래윗',
#  '조차',
#  '한데',
#  '그럼에도 불구하고',
#  '여전히',
#  '심지어',
#  '까지도',
#  '조차도',
#  '하지 않도록',
#  '않기 위하여',
#  '때',
#  '시각',
#  '무렵',
#  '시간',
#  '동안',
#  '어때',
#  '어떠한',
#  '하여금',
#  '네',
#  '예',
#  '우선',
#  '누구',
#  '누가 알겠는가',
#  '아무도',
#  '줄은모른다',
#  '줄은 몰랏다',
#  '하는 김에',
#  '겸사겸사',
#  '하는바',
#  '그런 까닭에',
#  '한 이유는',
#  '그러니',
#  '그러니까',
#  '때문에',
#  '그',
#  '너희',
#  '그들',
#  '너희들',
#  '타인',
#  '것',
#  '것들',
#  '너',
#  '위하여',
#  '공동으로',
#  '동시에',
#  '하기 위하여',
#  '어찌하여',
#  '무엇때문에',
#  '붕붕',
#  '윙윙',
#  '나',
#  '우리',
#  '엉엉',
#  '휘익',
#  '윙윙',
#  '오호',
#  '아하',
#  '어쨋든',
#  '만 못하다\t하기보다는',
#  '차라리',
#  '하는 편이 낫다',
#  '흐흐',
#  '놀라다',
#  '상대적으로 말하자면',
#  '마치',
#  '아니라면',
#  '쉿',
#  '그렇지 않으면',
#  '그렇지 않다면',
#  '안 그러면',
#  '아니었다면',
#  '하든지',
#  '아니면',
#  '이라면',
#  '좋아',
#  '알았어',
#  '하는것도',
#  '그만이다',
#  '어쩔수 없다',
#  '하나',
#  '일',
#  '일반적으로',
#  '일단',
#  '한켠으로는',
#  '오자마자',
#  '이렇게되면',
#  '이와같다면',
#  '전부',
#  '한마디',
#  '한항목',
#  '근거로',
#  '하기에',
#  '아울러',
#  '하지 않도록',
#  '않기 위해서',
#  '이르기까지',
#  '이 되다',
#  '로 인하여',
#  '까닭으로',
#  '이유만으로',
#  '이로 인하여',
#  '그래서',
#  '이 때문에',
#  '그러므로',
#  '그런 까닭에',
#  '알 수 있다',
#  '결론을 낼 수 있다',
#  '으로 인하여',
#  '있다',
#  '어떤것',
#  '관계가 있다',
#  '관련이 있다',
#  '연관되다',
#  '어떤것들',
#  '에 대해',
#  '이리하여',
#  '그리하여',
#  '여부',
#  '하기보다는',
#  '하느니',
#  '하면 할수록',
#  '운운',
#  '이러이러하다',
#  '하구나',
#  '하도다',
#  '다시말하면',
#  '다음으로',
#  '에 있다',
#  '에 달려 있다',
#  '우리',
#  '우리들',
#  '오히려',
#  '하기는한데',
#  '어떻게',
#  '어떻해',
#  '어찌됏어',
#  '어때',
#  '어째서',
#  '본대로',
#  '자',
#  '이',
#  '이쪽',
#  '여기',
#  '이것',
#  '이번',
#  '이렇게말하자면',
#  '이런',
#  '이러한',
#  '이와 같은',
#  '요만큼',
#  '요만한 것',
#  '얼마 안 되는 것',
#  '이만큼',
#  '이 정도의',
#  '이렇게 많은 것',
#  '이와 같다',
#  '이때',
#  '이렇구나',
#  '것과 같이',
#  '끼익',
#  '삐걱',
#  '따위',
#  '와 같은 사람들',
#  '부류의 사람들',
#  '왜냐하면',
#  '중의하나',
#  '오직',
#  '오로지',
#  '에 한하다',
#  '하기만 하면',
#  '도착하다',
#  '까지 미치다',
#  '도달하다',
#  '정도에 이르다',
#  '할 지경이다',
#  '결과에 이르다',
#  '관해서는',
#  '여러분',
#  '하고 있다',
#  '한 후',
#  '혼자',
#  '자기',
#  '자기집',
#  '자신',
#  '우에 종합한것과같이',
#  '총적으로 보면',
#  '총적으로 말하면',
#  '총적으로',
#  '대로 하다',
#  '으로서',
#  '참',
#  '그만이다',
#  '할 따름이다',
#  '쿵',
#  '탕탕',
#  '쾅쾅',
#  '둥둥',
#  '봐',
#  '봐라',
#  '아이야',
#  '아니',
#  '와아',
#  '응',
#  '아이',
#  '참나',
#  '년',
#  '월',
#  '일',
#  '령',
#  '영',
#  '일',
#  '이',
#  '삼',
#  '사',
#  '오',
#  '육',
#  '륙',
#  '칠',
#  '팔',
#  '구',
#  '이천육',
#  '이천칠',
#  '이천팔',
#  '이천구',
#  '하나',
#  '둘',
#  '셋',
#  '넷',
#  '다섯',
#  '여섯',
#  '일곱',
#  '여덟',
#  '아홉',
#  '령',
#  '영']

# %%
# ‘ko_text’ 피처에 get_nouns() 함수를 적용하여 불용어 및 한글자를 제거한 명사 추출하여 'nouns' 피처 생성
df['nouns'] = df['ko_text'].apply(lambda x: get_nouns(x))
print(df.shape) # 행과 열의 갯수를 튜플로 반환
df.head()
# Out:
# (1000, 4)
#                           created  \
# 0  Thu Feb 10 01:14:39 +0000 2022
# 1  Thu Feb 10 01:14:38 +0000 2022
# 2  Thu Feb 10 01:14:37 +0000 2022
# 3  Thu Feb 10 01:14:36 +0000 2022
# 4  Thu Feb 10 01:14:36 +0000 2022
#
#                                           tweet_text  \
# 0  RT @Citizen1Quiet: 이제 곧 한국대사관에 가서 이재명 찍을 날이 온다...
# 1  RT @uyhgw139vxlog: 이낙연과 거리를 좁혀 쬐끔만이라도 지지자를 땡겨 ...
# 2         RT @tadadadandan: 김혜경 이재명 구속이 아니면 속보가 아니지!
# 3  RT @Jaemyung_Lee: '나를 위한' 이재명의 소확행 공약! - 전세사기 ...
# 4  RT @yukimjun: 정홍원, 이재명에 "이런 사람이 최고지도자?..상상만 해도...
#
#                                              ko_text  \
# 0    이제 곧 한국대사관에 가서 이재명 찍을 날이 온다절대로 윤석열 같은 쓰레기에게 ...
# 1    이낙연과 거리를 좁혀 쬐끔만이라도 지지자를 땡겨 가려는 이재명의 불순한 음모를 ...
# 2                            김혜경 이재명 구속이 아니면 속보가 아니지
# 3    나를 위한 이재명의 소확행 공약  전세사기 편피 땀 눈물 흘려 마련한 전세보증금...
# 4          정홍원 이재명에 이런 사람이 최고지도자상상만 해도 얼굴 화끈팩폭이네ㅋㅋㅋㅋ
#
#                                                nouns
# 0          [이제, 한국, 대사관, 이재명, 절대로, 윤석열, 쓰레기, 나라, 명운]
# 1  [이낙연, 거리, 지지자, 이재명, 불순, 음모, 원천, 봉쇄, 측면, 추미애, 발...
# 2                                 [김혜경, 이재명, 구속, 속보]
# 3  [이재명, 확행, 공약, 전세, 사기, 편피, 눈물, 마련, 전세, 보증금, 서민,...
# 4        [정홍원, 이재명, 사람, 최고, 지도자, 상상, 해도, 얼굴, 화끈, 팩폭]

# %% [markdown]
# -----

# %% [markdown]
# # <Step3. 분석> : 연관 분석을 이용한 키워드 분석

# %% [markdown]
# ### [연관 키워드 추출하기]

# %% [markdown]
# ### [연관 규칙]
# - https://ratsgo.github.io/machine%20learning/2017/04/08/apriori/
# - 연관규칙 (아프리오리, Apriori 알고리즘) https://blog.naver.com/zzz90zzz/221807210555
# - 연관규칙은 비지도학습으로 대규모 거래 데이터로 부터 함께 구매될 규칙을 도출하여 고객이 특정 상품 구매시 이와 연관성이 높은 상품을 추천하는 것
# - Apriori 알고리즘 : 간단한 성능 측정치를 이용해 거대한 DB에서 데이터간의 연관성을 찾는 알고리즘
# ### [ 연관규칙에서 사용하는 3가지 통계척도 ]
# - 1. 지지도 (support)  : 특정 아이템이 데이터에서 발생하는 빈도
# - 2. 신뢰도 (confidence) : 두 아이템의 연관규칙이 유용한 규칙일 가능성의 척도
# - 3. 향상도 (lift) : 두 아이템의 연관 규칙이 우연인지 아닌지를 나타내는 척도
#
# - 아래 코드 실행을 위해, anaconda prompt 혹은 Terminal에서 아래와 같은 패키지들을 설치
#     - (env_name) `pip install apriori apyori`
# - 혹은 아래의 코드로 라이브러리를 설치

# %%
#!pip install apriori apyori
# Out:
# Collecting apriori
#   Downloading apriori-1.0.0.tar.gz (1.8 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting apyori
#   Downloading apyori-1.1.2.tar.gz (8.6 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Building wheels for collected packages: apriori, apyori
#   Building wheel for apriori (setup.py): started
#   Building wheel for apriori (setup.py): finished with status 'done'
#   Created wheel for apriori: filename=apriori-1.0.0-py3-none-any.whl size=2477 sha256=fd73d2ba7d332a50e03489be78c3c1c9a269db35ddf89600c2380f27ff023627
#   Stored in directory: c:\users\yj\appdata\local\pip\cache\wheels\e5\13\06\4f2e9149db374a829b7ee97bad99c9abffbf30976a81779b1c
#   Building wheel for apyori (setup.py): started
#   Building wheel for apyori (setup.py): finished with status 'done'
#   Created wheel for apyori: filename=apyori-1.1.2-py3-none-any.whl size=5974 sha256=3b3b743f4f1ec1802f731b3099f95cf4ac301e79d8cd01a4a4ad9e80f77791a1
#   Stored in directory: c:\users\yj\appdata\local\pip\cache\wheels\32\2a\54\10c595515f385f3726642b10c60bf788029e8f3a1323e3913a
# Successfully built apriori apyori
# Installing collected packages: apyori, apriori
# Successfully installed apriori-1.0.0 apyori-1.1.2

# %% [markdown]
# ##### 연관 분석 연습

# %%
##### 연관 분석 연습 1
from apyori import apriori

# 장바구니 형태의 데이터(트랜잭션 데이터)를 생성
transactions = [
    ['손흥민', '시소코'],
    ['손흥민', '케인'],
    ['손흥민', '케인', '포체티노']
]

# 연관 분석을 수행
results = list(apriori(transactions))
for result in results:
    print(result)
# Out:
# RelationRecord(items=frozenset({'손흥민'}), support=1.0, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'손흥민'}), confidence=1.0, lift=1.0)])
# RelationRecord(items=frozenset({'시소코'}), support=0.3333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'시소코'}), confidence=0.3333333333333333, lift=1.0)])
# RelationRecord(items=frozenset({'케인'}), support=0.6666666666666666, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'케인'}), confidence=0.6666666666666666, lift=1.0)])
# RelationRecord(items=frozenset({'포체티노'}), support=0.3333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'포체티노'}), confidence=0.3333333333333333, lift=1.0)])
# RelationRecord(items=frozenset({'손흥민', '시소코'}), support=0.3333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'손흥민', '시소코'}), confidence=0.3333333333333333, lift=1.0), OrderedStatistic(items_base=frozenset({'손흥민'}), items_add=frozenset({'시소코'}), confidence=0.3333333333333333, lift=1.0), OrderedStatistic(items_base=frozenset({'시소코'}), items_add=frozenset({'손흥민'}), confidence=1.0, lift=1.0)])
# RelationRecord(items=frozenset({'손흥민', '케인'}), support=0.6666666666666666, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'손흥민', '케인'}), confidence=0.6666666666666666, lift=1.0), OrderedStatistic(items_base=frozenset({'손흥민'}), items_add=frozenset({'케인'}), confidence=0.6666666666666666, lift=1.0), OrderedStatistic(items_base=frozenset({'케인'}), items_add=frozenset({'손흥민'}), confidence=1.0, lift=1.0)])
# RelationRecord(items=frozenset({'손흥민', '포체티노'}), support=0.3333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'손흥민', '포체티노'}), confidence=0.3333333333333333, lift=1.0), OrderedStatistic(items_base=frozenset({'손흥민'}), items_add=frozenset({'포체티노'}), confidence=0.3333333333333333, lift=1.0), OrderedStatistic(items_base=frozenset({'포체티노'}), items_add=frozenset({'손흥민'}), confidence=1.0, lift=1.0)])
# RelationRecord(items=frozenset({'포체티노', '케인'}), support=0.3333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'포체티노', '케인'}), confidence=0.3333333333333333, lift=1.0), OrderedStatistic(items_base=frozenset({'케인'}), items_add=frozenset({'포체티노'}), confidence=0.5, lift=1.5), OrderedStatistic(items_base=frozenset({'포체티노'}), items_add=frozenset({'케인'}), confidence=1.0, lift=1.5)])
# RelationRecord(items=frozenset({'손흥민', '포체티노', '케인'}), support=0.3333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'손흥민', '포체티노', '케인'}), confidence=0.3333333333333333, lift=1.0), OrderedStatistic(items_base=frozenset({'손흥민'}), items_add=frozenset({'포체티노', '케인'}), confidence=0.3333333333333333, lift=1.0), OrderedStatistic(items_base=frozenset({'케인'}), items_add=frozenset({'손흥민', '포체티노'}), confidence=0.5, lift=1.5), OrderedStatistic(items_base=frozenset({'포체티노'}), items_add=frozenset({'손흥민', '케인'}), confidence=1.0, lift=1.5), OrderedStatistic(items_base=frozenset({'손흥민', '케인'}), items_add=frozenset({'포체티노'}), confidence=0.5, lift=1.5), OrderedStatistic(items_base=frozenset({'손흥민', '포체티노'}), items_add=frozenset({'케인'}), confidence=1.0, lift=1.5), OrderedStatistic(items_base=frozenset({'포체티노', '케인'}), items_add=frozenset({'손흥민'}), confidence=1.0, lift=1.0)])

# %%
##### 연관 분석 연습 2
# 지지도 0.5, 신뢰도 0.6, 향상도 1.0 이상이면서 (손흥민, 케인) 처럼 규칙의 크기가 2 이하인 규칙을 추출
list(apriori(transactions,
             min_support=0.5,
             min_confidence=0.6,
             min_lift=1.0,
             max_length=2))
# Out:
# [RelationRecord(items=frozenset({'손흥민'}), support=1.0, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'손흥민'}), confidence=1.0, lift=1.0)]),
#  RelationRecord(items=frozenset({'케인'}), support=0.6666666666666666, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'케인'}), confidence=0.6666666666666666, lift=1.0)]),
#  RelationRecord(items=frozenset({'손흥민', '케인'}), support=0.6666666666666666, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'손흥민', '케인'}), confidence=0.6666666666666666, lift=1.0), OrderedStatistic(items_base=frozenset({'손흥민'}), items_add=frozenset({'케인'}), confidence=0.6666666666666666, lift=1.0), OrderedStatistic(items_base=frozenset({'케인'}), items_add=frozenset({'손흥민'}), confidence=1.0, lift=1.0)])]

# %% [markdown]
# -----

# %% [markdown]
# ##### 트위터 연관 키워드 분석

# %%
# 트랜잭션 데이터를 추출
transactions = df['nouns'].tolist()
#transactions = [transaction for transaction in transactions if transaction] # 공백 문자열을 방지
print(transactions)
# Out:
# [['이제', '한국', '대사관', '이재명', '절대로', '윤석열', '쓰레기', '나라', '명운'], ['이낙연', '거리', '지지자', '이재명', '불순', '음모', '원천', '봉쇄', '측면', '추미애', '발언', '땡큐', '평가'], ['김혜경', '이재명', '구속', '속보'], ['이재명', '확행', '공약', '전세', '사기', '편피', '눈물', '마련', '전세', '보증금', '서민', '주거', '안정', '위협', '사회', '범죄', '도지사', '깡통', '전세', '피해
피', '눈물', '마련', '전세', '보증금', '서민', '주거', '안정', '위협', '사회', '범죄', '도지사', '깡통', '전세', '피해', '예방', '상담', '센터', '전국'], ['문프', '정상', '문재인', '감빵', '가치관', '사고', '흐름', '정상', '박근혜', '감빵', '윤석열', '감옥', '이재명', '가치관'], ['화법', '대해', '깨달음', '이재명'], ['김재원', '민주당', '김재원', '이해찬', '정치', '보복', '친문', '자해', '공갈', '이재명', '출처', '뉴스', '네이버', '뉴스'], ['책임', '전형', '범인', '어법', '기관', '박도', '증거', '책임', '스스로', '먼저', '잘못', '일반', '사람'], ['이재명', '확행', '공약', '전세', '사기', '편피', '눈물', '마련', '전세', '보증금', '서민', '주거', '안정', '위협', '사회', '범죄', '도지사', '깡통', '전세', '피해', '예방', '상담', '센터', '전국'], ['예전', '문재인', '대통령', '대선', '펀드', '모금', '인증샷', '이재명', '펀드', '모금', '인증샷', '보신'], ['다행', '유인태', '덕분', '이재명', '최소', '유인태', '걱정'], ['시점', '역전', '샤이표', '제외', '언론', '여론', '주도', '다시', '이재명', '지배', '파급', '폭탄', '카드', '캠프', '준비'], ['이재명', '확행', '공약', '펫샵', '유기묘', '구조해', '동물보호', '소입', '보호', '소라', '이름', '신종', '펫샵', '반려동물', '이윤', '추구', '수단', '변질', '윤리'], ['윤석열', '국민', '펀드', '출시', '이자', '합산', '국민', '펀드', '목표', '억원', '집기', '모금', '완료', '클라우드', '펀드', '방식', '이재명', '금액', '수도'], ['이재명', '기관', '재판', '기관', '화천', '대유', '선관위', '수사', '수사'], ['이제', '한국', '대사관', '이재명', '절대로', '윤석열', '쓰레기', '나라', '명운'], ['정홍원', '이재명', '사람', '최고', '지도자', '상상', '해도', '얼굴', '화끈', '팩폭'], ['문제', '현수막', '비용', '후원', '후원자', '계좌', '추적', '행위', '이해', '안감', '선거법', '위반', '현수막', '제작비', '시민', '위반', '건가', '도대체', '누가', '고발', '명목', '고발', '부분'], ['대선', '후보', '명의', '캠프', '참여', '주요', '인사', '가운데', '범죄', '이력', '분석', '결과', '음주운전', '선거법', '위반', '횡령', '배임', '정치자금', '위반', '알선', '수재', '중범죄', '이력', '자만', '추렸더'], ['문프', '정상', '문재인', '감빵', '가치관', '사고', '흐름', '정상', '박근혜', '감빵', '윤석열', '감옥', '이재명', '가치관'], ['김재원', '문프', '지지', '이 ...

# %%
# 연관 분석을 수행
results = list(apriori(transactions,
                       min_support=0.05,
                       min_confidence=0.1,
                       min_lift=5,
                       max_length=2))
print(results)
# Out:
# [RelationRecord(items=frozenset({'깡통', '공약'}), support=0.057, ordered_statistics=[OrderedStatistic(items_base=frozenset({'공약'}), items_add=frozenset({'깡통'}), confidence=0.6951219512195121, lift=11.984861227922623), OrderedStatistic(items_base=frozenset({'깡통'}), items_add=frozenset({'공약'}), confidence=0.9827586206896551, lift=11.984861227922623)]), RelationRecord(items=frozenset({'공약', '눈물'}), support=0.057, ordered_statistics=[OrderedStatistic(items_base=frozenset({'공약'}), items_add=frozenset({'눈물'}), confidence=0.6951219512195121, lift=10.532150776053214), OrderedStatistic(items_base=frozenset({'눈물'}), items_add=frozenset({'공약'}), confidence=0.8636363636363636, lift=10.532150776053214)]), RelationRecord(items=frozenset({'도지사', '공약'}), support=0.057, ordered_statistics=[OrderedStatistic(items_base=frozenset({'공약'}), items_add=frozenset({'도지사'}), confidence=0.6951219512195121, lift=9.522218509856332), OrderedStatistic(items_base=frozenset({'도지사'}), items_add=frozenset({'공약'}), confidence=0.7808219178082193, lift=9.522218509856332)]), RelationRecord(items=frozenset({'마련', '공약'}), support=0.057, ordered_statistics=[OrderedStatistic(items_base=frozenset({'공약'}), items_add=frozenset({'마련'}), confidence=0.6951219512195121, lift=11.984861227922623), OrderedStatistic(items_base=frozenset({'마련'}), items_add=frozenset({'공약'}), confidence=0.9827586206896551, lift=11.984861227922623)]), RelationRecord(items=frozenset({'범죄', '공약'}), support=0.057, ordered_statistics=[OrderedStatistic(items_base=frozenset({'공약'}), items_add=frozenset({'범죄'}), confidence=0.6951219512195121, lift=9.027557808045612), OrderedStatistic(items_base=frozenset({'범죄'}), items_add=frozenset({'공약'}), confidence=0.7402597402597403, lift=9.027557808045612)]), RelationRecord(items=frozenset({'보증금', '공약'}), support=0.057, ordered_statistics=[OrderedStatistic(items_base=frozenset({'공약'}), items_add=frozenset({'보증금'}), confidence=0.6951219512195121, lift=12.19512195121951), OrderedStatistic(items_base=frozenset({'보증금'}), items_add=frozenset({'공약'}), confidence=1.0, lift=12.195121951219512)]), RelationRecord(items=frozenset({'사기', '공약'}), support=0.057, ordered_statistics=[OrderedStatistic(items_base=frozenset({'공약'}), items_add=frozenset({'사기'}), confidence=0.6951219512195121, lift=12.19512195121951), OrderedStatistic(items_base=frozenset({'사기'}), items_add=frozenset({'공약'}), confidence=1.0, lift=12.195121951219512)]), RelationRecord(items=frozenset({'공약', '사회'}), support=0.057, ordered_statistics=[OrderedStatistic(items_base=frozenset({'공약'}), items_add=frozenset({'사회'}), confidence=0.6951219512195121, lift=11.39544182327069), OrderedStatistic(items_base=frozenset({'사회'}), items_add=frozenset({'공약'}), confidence=0.9344262295081968, lift=11.395441823270692)]), RelationRecord(items=frozenset({'공약', '상담'}), support=0.057, ordered_statistics=[OrderedStatistic(items_base=frozenset({'공약'}), items_add=frozenset({'상담'}), confidence=0.6951219512195121, lift=12.19512195121951), OrderedStatistic(items_base=frozenset({'상담'}), items_add=frozenset({'공약'}), confidence=1.0, lift=12.195121951219512)]), RelationRecord(items=frozenset({'공약', '서민'}), support=0.057, ordered_statistics=[OrderedStatistic(items_base=frozenset({'공약'}), items_add=frozenset({'서민'}), confidence=0.6951219512195121, lift=11.984861227922623), OrderedStatistic(items_base=frozenset({'서민'}), items_add=frozenset({'공약'}), confidence=0.9827586206896551, lift=11.984861227922623)]), RelationRecord(items=frozenset({'센터', '공약'}), support=0.056, ordered_statistics=[OrderedStatistic(items_base=frozenset({'공약'}), items_add=frozenset({'센터'}), confidence=0.6829268292682926, lift=12.19512195121951), OrderedStatistic(items_base=frozenset({'센터'}), items_add=frozenset({'공약'}), confidence=1.0, lift=12.195121951219512)]), RelationRecord(items=frozenset({'공약', '안정'}), support=0.057, ordered_statistics=[OrderedStatistic(items_base=frozenset({'공약'}), items_add=frozenset({'안정'}), confidence=0.6951219512195121, lift=12.19512195121951), OrderedSta ...

# %%
# 데이터 프레임 형태로 정리
columns = ['source', 'target', 'support']
network_df = pd.DataFrame(columns=columns)

# 규칙의 조건절을 source, 결과절을 target, 지지도를 support 라는 데이터 프레임의 피처로 변환
for result in results:
    if len(result.items) == 2:
        items = [x for x in result.items]
        row = [items[0], items[1], result.support]
        series = pd.Series(row, index=network_df.columns)
        network_df = network_df.append(series, ignore_index=True)

network_df.head()
# Out:
#   source target  support
# 0     깡통     공약    0.057
# 1     공약     눈물    0.057
# 2    도지사     공약    0.057
# 3     마련     공약    0.057
# 4     범죄     공약    0.057

# %% [markdown]
# -----

# %% [markdown]
# ### [단어 빈도 추출하기]

# %% [markdown]
# ##### 말뭉치 추출

�어졌다유인태가 정신차릴까봐 걱정했다   현 시점에서 역전하려면 있기는 있지만 얼마나 될지 모르는 샤이표는 일단 제외하고 언론과 여론 주도권을 다시 이재명이 지배해야함 그럴만한 파급력 있는 폭탄적 카드를 당이나 캠프가 준비하고 있으면 좋겠는데  나를 위한 이재명의 소확행 공약  펫샵 편유기묘 구조해 믿고 맡겼던 동물보호소입양하려면 돈을 내라고보호소라는 이름을 내건 신종 펫샵반려동물을 이윤 추구 수단으로 변질시키는비윤리적 행  윤석열 국민펀드 출시연  이자 합산해 돌려준다 국민펀드의 목표액은 총 억원이며 모집기간은 모금 완료 시까지다  클라우드 펀드방식이고 이재명 보다 모금액수도  이재명은  수사기관과  재판기관  만큼은  확실히   화천대유  돈을  거하게  풀었나  보네  아  선관위도  수사해야  할곳과  수사하지 말아야 할곳이 뒤바뀐게  이제 곧 한국대사관에 가서 이재명 찍을 날이 온다절대로 윤석열 같은 쓰레기에게 이 나라의 명운을 넘길 수 없다  정홍원 이재명에 이런 사람이 최고지도자상상만 해도 얼굴 화끈팩폭이네ㅋㅋㅋㅋ  문제는 현수막 비용을 후원한 후원자의 계좌까지 추적해 잡아내는 행위는 이해가 안감 선거법위반 현수막의 제작비를 댄 시민도 위반인건가 도대체 누가 고발을 한 것이고 어떤 명목으로 고발을 한 것인지 우선 그 부분부  대선 후보 명의 캠프에 참여하고 있는 주요 인사 가운데 범죄이력이 있는 명을 분석한 결과 음주운전 명 선거법 위반 명으로 나타났습니다 횡령과 배임 정치자금법 위반 알선수재 같은 중범죄 이력자만 추렸더니  문프 지키고싶어서 둠 찍음  정상문재인 감빵보내거나 죽이고싶어서 윤 찍음  가치관은 불쾌하지만 사고의 흐름은 정상적박근혜 감빵보낸 윤석열이 괘씸해서 윤 감옥에 보내려고 이재명 찍음  가치관은 불쾌하지만 사  김재원 문프 지지하는 문파들중에 이재명은 죽어도 안뽑는다는 사람들 상대로 이해찬이 어제 윤석열 발언을 두고 저봐 윤석열 뽑으면 문프 큰일나 그러니까 이재명 뽑아야해라고 공갈치는거라고 말함그 문파들을  예전에 문재인 대통령 대선 펀드 모금할 때 되면 에 인증샷이 넘쳐났는데 이재명 펀드 모금에 인증샷 보신 분  김만배 통장  현금 인출  조폭들  이재명 펀드 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ  나를 위한 이재명의 소확행 공약  펫샵 편유기묘 구조해 믿고 맡겼던 동물보호소입양하려면 돈을 내라고보호소라는 이름을 내건 신종 펫샵반려동물을 이윤 추구 수단으로 변질시키는비윤리적 행  이재명 중국 춘절 맞춰 새해인사 보낸거이번에도 또 한거야 쟨 중국에 뭐가 있다고  ...

# %%
from konlpy.tag import Okt
from collections import Counter

# 명사 키워드를 추출, 빈도수 계산
nouns_tagger = Okt()
nouns = nouns_tagger.nouns(tweet_corpus)
count = Counter(nouns)

# 한글자 키워드를 제거
remove_char_counter = Counter({x : count[x] for x in count if len(x) > 1})
리스크': 15, '전과': 15, '가면': 15, '배우자': 15, '스토킹': 15, '어제': 14, '유지': 14, '명령': 14, '저런': 14, '자해': 14, '공갈': 14, '방식': 14, '화천': 14, '이해': 14, '선거법': 14, '경찰서': 14, '주변': 14, '모두': 14, '재수': 14, '사찬': 14, '의전': 14, '커녕': 13, '자금': 13, '먼저': 13, '억원': 13, '이번': 13, '용적률': 13, '상황': 13, '직접': 13, '세금': 13, '프레임': 13, '지지율': 13, '수원지검': 13, '정도': 13, '진영': 13, '고위': 13, '재산': 13, '의혹': 13, '전담': 13, '전혀': 13, '쓰레기': 12, '상대로': 12, '압색': 12, '혐의': 12, '승리': 12, '차병원': 12, '일반': 12, '추적': 12, '안감': 12, '도대체': 12, '우선': 12, '부분': 12, '윤석렬': 12, '대변인': 12, '부산': 12, '낙선': 12, '박은정': 12, '지청장': 12, '총장': 12, '자동': 12, '생활': 12, '자업자득': 12, '득표': 12, '입장': 12, '가정': 12, '파탄': 12, '진보': 12, '내각제': 12, '해명': 12, '모씨': 12, '관사': 12, '큰일': 11, '말함그': 11, '스톱': 11, '입금': 11, '카드': 11, '이자': 11, '비용': 11, '후원자': 11, '제작비': 11, '명목': 11, '퇴임': 11, '심상정': 11, '요청': 11, '수행': 11, '사도': 11, '성남시': 11, '보답': 11, '대박': 11, '훌쩍': 11, '사카': 11, '업무': 11, '처음': 11, '약자': 11, '배씨': 11, '특채': 11, '자기': 10, '병원': 10, '대표': 10, '관심': 10, '금액': 10, '답변': 10, '관용': 10, '차량': 10, '손실': 10, '시킴': 10, '변호사': 10, '발끈': 10, '결정': 10, '국고': 10, '진상': 10, '누구': 10, '코인': 10, '피해자': 10, '제발': 10, '교수': 10, '위원': 10, '내용': 10, '사적': 10, '완전': 10, '대한민국': 10, '노무현': 10, '지역': 10, '온라인': 10, '처벌': 10, '권한': 10, '네거티브': 10, '종자': 10, '임자': 10, '전화': 10, '당원': 9, '사고': 9, '기관': 9, '현재': 9, '응답': 9, '블랙요원': 9, '바로': 9, '인터뷰': 9, '제사': 9, '음식': 9, '동원': 9, '절대': 9, '여니': 9, '편이': 9, '주체': 9, '사태': 9, '출신': 9, '자문': 9, '간다': 9, '빡세': 9, '인식': 9, '보기': 9, '일화': 9, '논란': 9, '채용': 9, '추진': 9, '거나': 9, '평가': 8, '위험': 8, '흐름': 8, '출시': 8, '합산': 8, '집기': 8, '완료': 8, '클라우드': 8, '수도': 8, '만배': 8, '신성': 8, '억울': 8, '위장': 8, '기사': 8, '행시': 8, '사기꾼': 8, '잠시': 8, '부터': 8, '답신': 8, '군인': 8, '베겨': 8, '사법부': 8, '국정원' ...

# %% [markdown]
# -----

# %% [markdown]
# ##### 단어 빈도 점수 추가

# %%
# 키워드와 키워드 빈도 점수를 ‘node’, ‘nodesize’ 라는 데이터 프레임의 피처로 생성
node_df = pd.DataFrame(remove_char_counter.items(), columns=['node', 'nodesize'])
node_df = node_df[node_df['nodesize'] >= 50] # 시각화의 편의를 위해 ‘nodesize’ 50 이하는 제거합니다.
node_df.head()
# Out:
#    node  nodesize
# 3   이재명      1214
# 5   윤석열       206
# 9   이낙연        75
# 21  김혜경       169
# 24   확행        72

# %% [markdown]
# -----

# %% [markdown]
# # <Step4. 시각화> : 연관 키워드 네트워크 시각화

# %% [markdown]
# ### [연관 키워드 네트워크 시각화]

# %% [markdown]
# - 아래 코드 실행을 위해, anaconda prompt 혹은 Terminal에서 아래와 같은 패키지를 설치해 줍니다.
#     - (env_name) `pip install networkx`
# - 혹은 아래의 코드로 라이브러리를 설치합니다.
# - networkx 버전 2.3 이하를 설치하는 경우, 아래 코드를 다음과 같이 바꿔주어야 합니다.
#     - `sizes = [G.nodes[node]['nodesize']*25 for node in G]` -> `sizes = [G.node[node]['nodesize']*25 for node in G]`

# %%
#!pip install networkx
# Out:
# Requirement already satisfied: networkx in c:\users\yj\anaconda3\lib\site-packages (2.6.3)

# %% [markdown]
# -----

# %%
import networkx as nx
plt.figure(figsize=(25,25))

# networkx 그래프 객체를 생성
G = nx.Graph()

# node_df의 키워드 빈도수를 데이터로 하여, 네트워크 그래프의 ‘노드’ 역할을 하는 원을 생성
for index, row in node_df.iterrows():
    G.add_node(row['node'], nodesize=row['nodesize'])
    
# network_df의 연관 분석 데이터를 기반으로, 네트워크 그래프의 ‘관계’ 역할을 하는 선을 생성
for index, row in network_df.iterrows():
    G.add_weighted_edges_from([(row['source'], row['target'], row['support'])])
    
# 그래프 디자인과 관련된 파라미터를 설정
pos = nx.spring_layout(G, k=0.6, iterations=50)
# nx.draw(G, pos=pos)
sizes = [G.nodes[node]['nodesize']*25 for node in G]
nx.draw(G, pos=pos, node_size=sizes,node_color='yellow')


# Windows 사용자는 AppleGothic 대신,'Malgun Gothic'. 그 외 OS는 OS에서 한글을 지원하는 기본 폰트를 입력
# nx.draw_networkx_labels(G, pos=pos, font_family='NanumGothic', font_size=25)
nx.draw_networkx_labels(G, pos=pos, font_family='Malgun Gothic', font_size=25)

# 그래프를 출력
ax = plt.gca()
plt.show()

# %%
newArray=[]
for i in range(100):
    if(i%2==1):
        newArray.append(i)

dicArray=[]
dic={}
for i in newArray:
    if(newArray.index(i)%2!=1):
        dic['name']=i
    if(newArray.index(i)%2==1):
        dic['value']=i
        dicArray.append(dic)
        dic={}
#     if(len(dic)==2):
#         dicArray.append(dic)
#         dic={}
        
print(dicArray)
# Out:
# [{'name': 1, 'value': 3}, {'name': 5, 'value': 7}, {'name': 9, 'value': 11}, {'name': 13, 'value': 15}, {'name': 17, 'value': 19}, {'name': 21, 'value': 23}, {'name': 25, 'value': 27}, {'name': 29, 'value': 31}, {'name': 33, 'value': 35}, {'name': 37, 'value': 39}, {'name': 41, 'value': 43}, {'name': 45, 'value': 47}, {'name': 49, 'value': 51}, {'name': 53, 'value': 55}, {'name': 57, 'value': 59}, {'name': 61, 'value': 63}, {'name': 65, 'value': 67}, {'name': 69, 'value': 71}, {'name': 73, 'value': 75}, {'name': 77, 'value': 79}, {'name': 81, 'value': 83}, {'name': 85, 'value': 87}, {'name': 89, 'value': 91}, {'name': 93, 'value': 95}, {'name': 97, 'value': 99}]
